# %% [markdown]
# ### Train a model on the imbalanced dataset

# %%
# # Run once to install
# !pip install image-classifiers==0.2.2
# !pip install image-classifiers==1.0.0b1
# !pip install imgaug

# %%
import sys
# !{sys.executable} -m pip install tensorflow==1.13.1
# tensorflow==1.13.1
# keras==2.2.4
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

# %tensorflow_version 1.x

import tensorflow
import keras
print(tensorflow.__version__)
print(keras.__version__)

import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# 1.15.2
# 2.3.1
# '/device:GPU:0'

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# Import libs
import os 
import time
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras import optimizers
import keras
import tensorflow as tf
import keras.backend as K
from sklearn.metrics import confusion_matrix, classification_report
from keras.models import load_model
from keras.models import Sequential
from keras.regularizers import l2
from keras.applications.vgg16 import VGG16
# from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
from tqdm import tqdm
from keras.utils import np_utils
from imgaug import augmenters as iaa    
import itertools

np.random.seed(42)

# Print version
print("Keras Version", keras.__version__)
print("Tensorflow Version", tf.__version__)


# GPU test
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())

# Get compute specs
from tensorflow.python.client import device_lib
device_lib.list_local_devices()



# Helpers functions
def create_directory(directory):
    '''
    Creates a new folder in the specified directory if the folder doesn't exist.
    INPUT
        directory: Folder to be created, called as "folder/".
    OUTPUT
        New folder in the current directory.
    '''
    if not os.path.exists(directory):
        os.makedirs(directory)


def plot_hist(img):
    
    img_flat = img.flatten()
    print(min(img_flat), max(img_flat))
    
    plt.hist(img_flat, bins=20, color='c')
    #plt.title("Data distribution")
    plt.xlabel("Pixel values")
    plt.grid(True)
    plt.ylabel("Frequency")
    
    plt.show()



from keras import backend as K
import tensorflow as tf

# Define paths
base_path = os.path.abspath("../")
# '/content/gdrive/My Drive/adversarial-xray/'
dataset_path = os.path.join(base_path, "dataset", "dataNumpy")

print(os.listdir(dataset_path))


# Load data
x_train = np.load("{}/x_train.npy".format(dataset_path)) 
y_train = np.load("{}/y_train.npy".format(dataset_path))
x_test = np.load("{}/x_test.npy".format(dataset_path))
y_test = np.load("{}/y_test.npy".format(dataset_path))


# Shuffle training dataset
flag = 1
if flag == 1:
    # Shuffle data
    print("Shuffling data")
    s = np.arange(x_train.shape[0])
    np.random.shuffle(s)
    x_train = x_train[s]
    y_train = y_train[s]
else:
    print("Not shuffling...")
    pass


# Show shape
print("Dataset sample size :", x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# check on training data
img = x_train[0]
plot_hist(img)

plt.imshow(x_train[0])
# Out:
# Keras Version 2.3.1
# Tensorflow Version 1.15.2
# ['/device:GPU:0']
# ['x_train.npy', 'y_train.npy', 'x_train_gan.npy', 'y_train_gan.npy', 'y_test.npy', 'x_test.npy', 'x_upsampled.npy', 'y_upsampled.npy', 'x_train_gan_p.npy', 'y_train_gan_p.npy', 'y_upsampled_.npy', 'x_upsampled_.npy', 'testX.npy', 'testY.npy']
# Shuffling data
# Dataset sample size : (2321, 256, 256, 3) (2321, 3) (580, 256, 256, 3) (580, 3)
# 0 254

# %%
len(x_train)
# Out:
# 2321

# %%
import keras
from keras.layers import Input

# preprocessing
prepro = True 

if prepro == True:
    print("Preprocessing training data")
    x_train = x_train.astype('float32')
    x_train /= 255
else:
    print("Not preprocessing training data, already preprocessed in MeGAN generator.")
    pass

# Standardize test set
x_test = x_test.astype('float32')
x_test /= 255

print(x_train.shape, x_test.shape)

# check on preprocessed data
img = x_test[0]
plot_hist(img)
plt.imshow(x_test[0])
# Out:
# Preprocessing training data
# (2321, 256, 256, 3) (580, 256, 256, 3)
# 0.0 1.0

# %%
# Experiment name
EXP_NAME = "results_before_GAN"

# Create folder for the experiment
create_directory("{}/{}".format(base_path, EXP_NAME))
output_path = os.path.join(base_path, EXP_NAME)


# Callbacks
weights_path = "{}/{}.h5".format(output_path, EXP_NAME)
checkpointer = ModelCheckpoint(filepath=weights_path, verbose=1, monitor='val_loss', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-8, mode='auto') # new_lr = lr * factor
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, verbose=1, patience=8, mode='auto', restore_best_weights=True)
csv_logger = CSVLogger('{}/{}_training.csv'.format(output_path, EXP_NAME))


# Define class weights 
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight(None, np.unique(np.argmax(y_train, axis=1)), np.argmax(y_train, axis=1))
print(class_weights)


def our_model():

    # Get backbone network
    input_tensor = Input(shape=(256, 256, 3))  

    base_model = VGG16(input_tensor=input_tensor, weights='imagenet', include_top=False)

    # Add GAP layer
    x = keras.layers.GlobalAveragePooling2D()(base_model.output)
    # Add FC layer
    output = keras.layers.Dense(3, activation='softmax', trainable=True)(x) 

    # Build model
    model = keras.models.Model(inputs=[base_model.input], outputs=[output])

    # Optimizers
    adadelta = optimizers.Adadelta(lr=0.001) 

    # Compile
    model.compile(optimizer=adadelta, loss= 'categorical_crossentropy', metrics=['accuracy']) 

    # Output model configuration
    model.summary()

    return model


model = None
model = our_model()
# Out:
# [1. 1. 1.]
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 14,716,227
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, random_state=42)

# Configuration
batch_size = 16
epochs = 100 

# Calculate the starting time    
start_time = time.time()


model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(x_val, y_val),
            class_weight = class_weights,
            callbacks=[csv_logger, early_stopping, reduce_lr, checkpointer], # early_stopping, checkpointer, reduce_lr
            shuffle=True)


end_time = time.time()
print("--- Time taken to train : %s hours ---" % ((end_time - start_time)//3600))
# Out:
# Train on 1484 samples, validate on 372 samples
# Epoch 1/100
# 1484/1484 [==============================] - 38s 26ms/step - loss: 0.8647 - accuracy: 0.6287 - val_loss: 0.7200 - val_accuracy: 0.8280
#
# Epoch 00001: val_loss improved from inf to 0.72000, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 2/100
# 1484/1484 [==============================] - 36s 24ms/step - loss: 0.6868 - accuracy: 0.7938 - val_loss: 0.5468 - val_accuracy: 0.8548
#
# Epoch 00002: val_loss improved from 0.72000 to 0.54681, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 3/100
# 1484/1484 [==============================] - 36s 25ms/step - loss: 0.5487 - accuracy: 0.8187 - val_loss: 0.4284 - val_accuracy: 0.8441
#
# Epoch 00003: val_loss improved from 0.54681 to 0.42844, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 4/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.4552 - accuracy: 0.8342 - val_loss: 0.3732 - val_accuracy: 0.8495
#
# Epoch 00004: val_loss improved from 0.42844 to 0.37319, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 5/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.3961 - accuracy: 0.8470 - val_loss: 0.3305 - val_accuracy: 0.8710
#
# Epoch 00005: val_loss improved from 0.37319 to 0.33052, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 6/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.3574 - accuracy: 0.8666 - val_loss: 0.2942 - val_accuracy: 0.8978
#
# Epoch 00006: val_loss improved from 0.33052 to 0.29416, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 7/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.3230 - accuracy: 0.8821 - val_loss: 0.2617 - val_accuracy: 0.8978
#
# Epoch 00007: val_loss improved from 0.29416 to 0.26173, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 8/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.3015 - accuracy: 0.8976 - val_loss: 0.2518 - val_accuracy: 0.9032
#
# Epoch 00008: val_loss improved from 0.26173 to 0.25180, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 9/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2731 - accuracy: 0.9043 - val_loss: 0.3385 - val_accuracy: 0.8710
#
# Epoch 00009: val_loss did not improve from 0.25180
# Epoch 10/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2577 - accuracy: 0.9117 - val_loss: 0.2274 - val_accuracy: 0.9194
#
# Epoch 00010: val_loss improved from 0.25180 to 0.22740, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 11/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2455 - accuracy: 0.9198 - val_loss: 0.2031 - val_accuracy: 0.9220
#
# Epoch 00011: val_loss improved from 0.22740 to 0.20312, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 12/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2303 - accuracy: 0.9245 - val_loss: 0.1891 - val_accuracy: 0.9247
#
# Epoch 00012: val_loss improved from 0.20312 to 0.18909, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 13/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2230 - accuracy: 0.9239 - val_loss: 0.2058 - val_accuracy: 0.9194
#
# Epoch 00013: val_loss did not improve from 0.18909
# Epoch 14/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2067 - accuracy: 0.9387 - val_loss: 0.1772 - val_accuracy: 0.9409
#
# Epoch 00014: val_loss improved from 0.18909 to 0.17725, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 15/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.2017 - accuracy: 0.9373 - val_loss: 0.1659 - val_accuracy: 0.9462
#
# Epoch 00015: val_loss improved from 0.17725 to 0.16591, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 16/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1909 - accuracy: 0.9373 - val_loss: 0.2391 - val_accuracy: 0.8871
#
# Epoch 00016: val_loss did not improve from 0.16591
# Epoch 17/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1848 - accuracy: 0.9394 - val_loss: 0.1604 - val_accuracy: 0.9516
#
# Epoch 00017: val_loss improved from 0.16591 to 0.16041, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 18/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1763 - accuracy: 0.9400 - val_loss: 0.1482 - val_accuracy: 0.9570
#
# Epoch 00018: val_loss improved from 0.16041 to 0.14824, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 19/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1727 - accuracy: 0.9488 - val_loss: 0.1485 - val_accuracy: 0.9516
#
# Epoch 00019: val_loss did not improve from 0.14824
# Epoch 20/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1658 - accuracy: 0.9501 - val_loss: 0.1426 - val_accuracy: 0.9462
#
# Epoch 00020: val_loss improved from 0.14824 to 0.14264, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 21/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1617 - accuracy: 0.9495 - val_loss: 0.1839 - val_accuracy: 0.9382
#
# Epoch 00021: val_loss did not improve from 0.14264
# Epoch 22/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1587 - accuracy: 0.9488 - val_loss: 0.1422 - val_accuracy: 0.9570
#
# Epoch 00022: val_loss improved from 0.14264 to 0.14220, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 23/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1532 - accuracy: 0.9542 - val_loss: 0.1484 - val_accuracy: 0.9597
#
# Epoch 00023: val_loss did not improve from 0.14220
# Epoch 24/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1464 - accuracy: 0.9542 - val_loss: 0.1283 - val_accuracy: 0.9597
#
# Epoch 00024: val_loss improved from 0.14220 to 0.12826, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 25/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1422 - accuracy: 0.9596 - val_loss: 0.1321 - val_accuracy: 0.9516
#
# Epoch 00025: val_loss did not improve from 0.12826
# Epoch 26/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1454 - accuracy: 0.9542 - val_loss: 0.1312 - val_accuracy: 0.9624
#
# Epoch 00026: val_loss did not improve from 0.12826
# Epoch 27/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1338 - accuracy: 0.9582 - val_loss: 0.1374 - val_accuracy: 0.9624
#
# Epoch 00027: val_loss did not improve from 0.12826
# Epoch 28/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1346 - accuracy: 0.9542 - val_loss: 0.1202 - val_accuracy: 0.9624
#
# Epoch 00028: val_loss improved from 0.12826 to 0.12015, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 29/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1327 - accuracy: 0.9569 - val_loss: 0.1165 - val_accuracy: 0.9651
#
# Epoch 00029: val_loss improved from 0.12015 to 0.11646, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 30/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1298 - accuracy: 0.9596 - val_loss: 0.1255 - val_accuracy: 0.9624
#
# Epoch 00030: val_loss did not improve from 0.11646
# Epoch 31/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1236 - accuracy: 0.9629 - val_loss: 0.1191 - val_accuracy: 0.9651
#
# Epoch 00031: val_loss did not improve from 0.11646
# Epoch 32/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1255 - accuracy: 0.9616 - val_loss: 0.1200 - val_accuracy: 0.9651
#
# Epoch 00032: val_loss did not improve from 0.11646
# Epoch 33/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1186 - accuracy: 0.9602 - val_loss: 0.1195 - val_accuracy: 0.9677
#
# Epoch 00033: val_loss did not improve from 0.11646
# Epoch 34/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1184 - accuracy: 0.9650 - val_loss: 0.1079 - val_accuracy: 0.9651
#
# Epoch 00034: val_loss improved from 0.11646 to 0.10795, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 35/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1166 - accuracy: 0.9629 - val_loss: 0.1163 - val_accuracy: 0.9624
#
# Epoch 00035: val_loss did not improve from 0.10795
# Epoch 36/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1109 - accuracy: 0.9677 - val_loss: 0.1091 - val_accuracy: 0.9624
#
# Epoch 00036: val_loss did not improve from 0.10795
# Epoch 37/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1147 - accuracy: 0.9656 - val_loss: 0.1131 - val_accuracy: 0.9704
#
# Epoch 00037: val_loss did not improve from 0.10795
# Epoch 38/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1098 - accuracy: 0.9663 - val_loss: 0.1076 - val_accuracy: 0.9677
#
# Epoch 00038: val_loss improved from 0.10795 to 0.10762, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 39/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1118 - accuracy: 0.9636 - val_loss: 0.1264 - val_accuracy: 0.9624
#
# Epoch 00039: val_loss did not improve from 0.10762
# Epoch 40/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1046 - accuracy: 0.9656 - val_loss: 0.0999 - val_accuracy: 0.9651
#
# Epoch 00040: val_loss improved from 0.10762 to 0.09993, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 41/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1034 - accuracy: 0.9677 - val_loss: 0.1069 - val_accuracy: 0.9651
#
# Epoch 00041: val_loss did not improve from 0.09993
# Epoch 42/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1018 - accuracy: 0.9697 - val_loss: 0.1021 - val_accuracy: 0.9704
#
# Epoch 00042: val_loss did not improve from 0.09993
# Epoch 43/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0979 - accuracy: 0.9677 - val_loss: 0.1867 - val_accuracy: 0.9274
#
# Epoch 00043: val_loss did not improve from 0.09993
# Epoch 44/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.1035 - accuracy: 0.9704 - val_loss: 0.0962 - val_accuracy: 0.9624
#
# Epoch 00044: val_loss improved from 0.09993 to 0.09624, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 45/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0948 - accuracy: 0.9737 - val_loss: 0.1032 - val_accuracy: 0.9704
#
# Epoch 00045: val_loss did not improve from 0.09624
# Epoch 46/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0986 - accuracy: 0.9656 - val_loss: 0.1361 - val_accuracy: 0.9570
#
# Epoch 00046: val_loss did not improve from 0.09624
# Epoch 47/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0937 - accuracy: 0.9690 - val_loss: 0.1021 - val_accuracy: 0.9704
#
# Epoch 00047: val_loss did not improve from 0.09624
# Epoch 48/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0913 - accuracy: 0.9697 - val_loss: 0.0917 - val_accuracy: 0.9677
#
# Epoch 00048: val_loss improved from 0.09624 to 0.09173, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 49/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0951 - accuracy: 0.9670 - val_loss: 0.0924 - val_accuracy: 0.9677
#
# Epoch 00049: val_loss did not improve from 0.09173
# Epoch 50/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0861 - accuracy: 0.9704 - val_loss: 0.0911 - val_accuracy: 0.9651
#
# Epoch 00050: val_loss improved from 0.09173 to 0.09112, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 51/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0836 - accuracy: 0.9710 - val_loss: 0.0911 - val_accuracy: 0.9704
#
# Epoch 00051: val_loss improved from 0.09112 to 0.09110, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 52/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0886 - accuracy: 0.9737 - val_loss: 0.0885 - val_accuracy: 0.9704
#
# Epoch 00052: val_loss improved from 0.09110 to 0.08850, saving model to /content/gdrive/My Drive/adversarial-xray/results_before_GAN/results_before_GAN.h5
# Epoch 53/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0871 - accuracy: 0.9697 - val_loss: 0.1001 - val_accuracy: 0.9731
#
# Epoch 00053: val_loss did not improve from 0.08850
# Epoch 54/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0811 - accuracy: 0.9730 - val_loss: 0.1180 - val_accuracy: 0.9651
#
# Epoch 00054: val_loss did not improve from 0.08850
# Epoch 55/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0828 - accuracy: 0.9744 - val_loss: 0.1236 - val_accuracy: 0.9624
#
# Epoch 00055: val_loss did not improve from 0.08850
# Epoch 56/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0786 - accuracy: 0.9751 - val_loss: 0.1341 - val_accuracy: 0.9543
#
# Epoch 00056: val_loss did not improve from 0.08850
# Epoch 57/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0824 - accuracy: 0.9744 - val_loss: 0.0949 - val_accuracy: 0.9731
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00057: val_loss did not improve from 0.08850
# Epoch 58/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0675 - accuracy: 0.9784 - val_loss: 0.0975 - val_accuracy: 0.9731
#
# Epoch 00058: val_loss did not improve from 0.08850
# Epoch 59/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0685 - accuracy: 0.9771 - val_loss: 0.0959 - val_accuracy: 0.9731
#
# Epoch 00059: val_loss did not improve from 0.08850
# Epoch 60/100
# 1484/1484 [==============================] - 37s 25ms/step - loss: 0.0682 - accuracy: 0.9784 - val_loss: 0.0923 - val_accuracy: 0.9758
# Restoring model weights from the end of the best epoch
#
# Epoch 00060: val_loss did not improve from 0.08850
# Epoch 00060: early stopping
# --- Time taken to train : 0.0 hours ---

# %%
# Save model
model.save(weights_path)

# %%
# Check model after saving
from keras.models import load_model
EXP_NAME = "results_before_GAN"

# Create folder for the experiment
create_directory("{}/{}".format(base_path, EXP_NAME))
output_path = os.path.join(base_path, EXP_NAME)
weights_path = "{}/{}.h5".format(output_path, EXP_NAME)

model_before_GAN = load_model(weights_path, custom_objects=None)

# %%
# Plot and save accuravy and loss graphs 
def plot_loss_accu(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(loss))
    plt.plot(epochs, loss, 'g')
    plt.plot(epochs, val_loss, 'y')
    plt.title('Training and validation loss before CycleGAN')
    plt.ylabel('Loss %')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.grid(True)
    plt.savefig('{}/{}_loss.jpg'.format(output_path, EXP_NAME), dpi=100)
    plt.show()
    
    loss = history.history['accuracy']
    val_loss = history.history['val_accuracy']
    epochs = range(len(loss))
    plt.plot(epochs, loss, 'r')
    plt.plot(epochs, val_loss, 'b')
    plt.title('Training and validation accuracy before CycleGAN')
    plt.ylabel('Accuracy %')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.grid(True)
    plt.savefig('{}/{}_acc.jpg'.format(output_path, EXP_NAME), dpi=100)
    plt.show()

# %%
plot_loss_accu(model.history)
print("Done training and logging!")

# %%
# Prepare Test Set
# Shuffle testing dataset
flag = 1
if flag == 1:
    # Shuffle data
    print("Shuffling data")
    s = np.arange(x_test.shape[0])
    np.random.shuffle(s)
    x_test = x_test[s]
    y_test = y_test[s]
else:
    print("Not shuffling...")
    pass
# Out:
# Shuffling data

# %%
# Convert one-hot-encoding to numeric labels
y_true = []
for i in range(len(y_test)):
    y_true.append(np.argmax(y_test[i], axis=None, out=None))
# print(y_true)

# %%
# predict test data
y_pred = []
for i in range(len(x_test)):
    img = x_test[i].reshape(1, 256, 256, 3)
    # print(img.shape)
    pred_prob = model.predict(img)
    # print(pred_prob)
    # convert the probabilities to class labels
    y_pred.append(np.argmax(pred_prob, axis=None, out=None))
print(y_pred)
# Out:
# [2, 2, 2, 0, 2, 2, 1, 0, 2, 2, 0, 0, 2, 0, 2, 0, 0, 0, 0, 0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 0, 2, 0, 0, 0, 0, 0, 2, 0, 2, 1, 2, 2, 0, 2, 2, 2, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0, 2, 0, 2, 0, 0, 0, 0, 2, 0, 2, 0, 2, 2, 0, 0, 1, 0, 0, 0, 0, 2, 0, 0, 2, 2, 0, 2, 0, 0, 0, 0, 0, 2, 0, 0, 2, 2, 1, 0, 0, 2, 2, 2, 2, 2, 2, 0, 0, 0, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 0, 2, 1, 2, 0, 0, 0, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 0, 1, 0, 2, 0, 0, 2, 1, 0, 0, 0, 2, 2, 2, 2, 0, 0, 2, 0, 1, 0, 0, 2, 0, 0, 1, 1, 1, 2, 1, 2, 2, 2, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 2, 0, 2, 0, 0, 2, 2, 0, 0, 2, 2, 0, 2, 0, 0, 2, 0, 2, 2, 2, 2, 0, 2, 0, 0, 0, 0, 1, 2, 2, 2, 0, 0, 1, 1, 2, 2, 2, 0, 2, 1, 0, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 2, 0, 2, 2, 0, 2, 0, 0, 2, 0, 2, 1, 2, 0, 0, 0, 2, 2, 0, 2, 0, 2, 0, 0, 1, 0, 0, 2, 0, 0, 0, 2, 0, 0, 0, 2, 2, 0, 0, 0, 1, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 2, 0, 0, 0, 0, 1, 0, 1, 2, 0, 0, 2, 0, 0, 2, 2, 0, 2, 2, 2, 2, 2, 1, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 0, 0, 0, 2, 0, 0, 2, 0, 2, 1, 2, 0, 2, 0, 1, 0, 0, 2, 0, 0, 0, 0, 2, 2, 2, 2, 0, 0, 0, 0, 1, 2, 2, 0, 1, 0, 2, 2, 0, 0, 0, 0, 2, 2, 0, 2, 0, 0, 0, 0, 0, 2, 2, 2, 0, 1, 2, 2, 0, 0, 0, 2, 0, 0, 0, 0, 1, 0, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 1, 0, 0, 1, 2, 0, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 1, 0, 1, 0, 1, 0, 0, 0, 0, 1, 0, 2, 0, 2, 2, 0, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 1, 2, 0, 2, 0, 0, 2, 0, 0, 2, 0, 2, 2, 2, 0, 0, 2, 1, 0, 0, 2, 0, 0, 2, 2, 0, 0, 0, 2, 1, 0, 2, 2, 2, 0, 2, 0, 2, 2, 0, 1, 2, 0, 1, 2, 2, 0, 0, 0, 2, 0, 2, 0, 0, 1, 1, 0, 0, 0, 2, 0, 2, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 2, 0, 2, 0, 0, 1, 0, 0, 0, 2, 2, 0, 0, 2, 0, 2, 1, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 2, 1, 1, 0, 0, 0, 2]

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig('{}/{}_cm.jpg'.format(output_path, EXP_NAME), dpi=300)
    plt.show()

# %%
cm = metrics.confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, 
                      normalize    = False,
                      target_names = ['NORMAL', 'COVID-19', 'PNEUMONIA'],
                      title        = "Confusion Matrix")

# %%
from sklearn import metrics

# Printing the confusion matrix
print(metrics.confusion_matrix(y_true, y_pred))
# Printing the precision and recall, among other metrics
print(metrics.classification_report(y_true, y_pred))
